# %%
import pandas as pd
import json
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.impute import SimpleImputer

# %%
raw_data = pd.read_csv("../../data/extracted_features/features/x5_llm_features_interns.csv")
raw_data.head()

# %%
df = raw_data.copy()
df["features_json"] = df['response'].apply(json.loads)

# %%
df = df[df['features_json'].notnull()].reset_index(drop=True)
df_expanded = pd.json_normalize(df['features_json'])
df_final = pd.concat([df_expanded, df['Hire status']], axis=1)
df_final
# Out:
#        gpa  cplus_plus_knowledge  csharp_knowledge  sql_knowledge  \
# 0      0.0                 False             False           True
# 1      4.0                 False             False           True
# 2      4.5                 False             False           True
# 3      0.0                 False             False           True
# 4      4.0                 False             False           True
# ..     ...                   ...               ...            ...
# 306    4.5                 False             False           True
# 307    4.0                 False             False          False
# 308    4.5                 False             False           True
# 309    4.5                 False             False           True
# 310  100.0                  True             False           True
#
#      python_knowledge  javascript_knowledge  java_knowledge  \
# 0                True                 False           False
# 1                True                 False           False
# 2                True                 False           False
# 3                True                 False           False
# 4                True                 False           False
# ..                ...                   ...             ...
# 306              True                 False           False
# 307              True                 False           False
# 308              True                 False           False
# 309              True                 False           False
# 310              True                 False           False
#
#      cloud_computing_skills  teamwork_skills  english_knowledge  ...  \
# 0                     False                3                  3  ...
# 1                     False                5                  3  ...
# 2                     False                5                  4  ...
# 3                     False                0                  0  ...
# 4                     False                3                  3  ...
# ..                      ...              ...                ...  ...
# 306                   False                3                  2  ...
# 307                   False                4                  4  ...
# 308                   False                5                  3  ...
# 309                   False                5                  5  ...
# 310                   False               10                  3  ...
#
#      education_type  university  experience_as_analyst  \
# 0                 1           1                  False
# 1                 1           2                  False
# 2                 1           1                   True
# 3                 0           0                   True
# 4                 1           1                  False
# ..              ...         ...                    ...
# 306               1           1                  False
# 307               4           4                  False
# 308               1           1                  False
# 309               1           1                  False
# 310               1           1                   True
#
#      experience_as_data_scientist  experience_as_machine_learning_engineer  \
# 0                           False                                    False
# 1                           False                                    False
# 2                            True                                    False
# 3                            True                                     True
# 4                           False                                    False
# ..                            ...                                      ...
# 306                          True                                    False
# 307                         False                                     True
# 308                          True                                     True
# 309                          True                                    False
# 310                         False                                    False
#
#      experience_as_backend_developer  experience_as_frontend_developer  \
# 0                              False                             False
# 1                               True                             False
# 2                              False                             False
# 3                              False                             False
# 4                              False                             False
# ..                               ...                               ...
# 306                            False                             False
# 307                            False                             False
# 308                            False                             False
# 309                            False                             False
# 310                            False                             False
#
#      conference_participation  hackathon_participation  Hire status
# 0                       False                    False            0
# 1                       False                     True            0
# 2                       False                    False            0
# 3                       False                    False            1
# 4                       False                    False            1
# ..                        ...                      ...          ...
# 306                     False                    False            1
# 307                     False                     True            0
# 308                     False                    False            0
# 309                     False                    False            1
# 310                     False                    False            1
#
# [311 rows x 23 columns]

# %%
X = df_final.iloc[:, :-1]
y = df_final.iloc[:, -1]

# %%
binary_features = X.select_dtypes(include=['bool']).columns
categorical_features = X.select_dtypes(include=['int64']).columns
numerical_features = X.select_dtypes(include=['float64']).columns

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('binary', 'passthrough', binary_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features),
        ('num', StandardScaler(), numerical_features)
    ],
    remainder='passthrough'
)

# %%
logistic_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(max_iter=1000))
])

gradient_boosting_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', GradientBoostingClassifier())
])

svm_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', SVC())
])

pipelines = [
    ('Logistic Regression', logistic_pipeline),
    ('Gradient Boosting', gradient_boosting_pipeline),
    ('SVM', svm_pipeline)
]

# %%
for name, pipeline in pipelines:
    scores = cross_val_score(pipeline, X, y, cv=5, scoring='roc_auc')
    print(f"{name} ROC-AUC: {scores.mean():.2f}")
# Out:
# Logistic Regression ROC-AUC: 0.50
# Gradient Boosting ROC-AUC: 0.50
# SVM ROC-AUC: 0.52

# %%
scores
# Out:
# array([0.46975806, 0.47138398, 0.6024974 , 0.51404787, 0.54994797])
